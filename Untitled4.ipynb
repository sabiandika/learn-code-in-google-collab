# %% [markdown]
# <a href="https://colab.research.google.com/github/sabiandika/learn-code-in-google-collab/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PYTHON BASIC PROGRAMMING**

# %% [markdown]
# FOR LOOP
#
#
#
# SYNTAX
#
# FOR ITEM IN SEQUENCE:
#
#    #CODE BLOCK

# %%
CAR = ["BMW", "MERCY", "AUDI"]
for i in CAR:
  print(i)
# Out:
# BMW
# MERCY
# AUDI

# %%
CAR = 6
for CAR in range(CAR):
  print(CAR)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# WHILE LOOP
#
#
#
# WHILE TRUE:
#   CODE BLOCK

# %%
ANGKA = 5
while ANGKA > 0:
  print(ANGKA)
  ANGKA -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# BREAK

# %%
for i in range(10):
  if i == 8:
    break
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# continue
#
#
# buat skip

# %%
for i in range(5):
  if i == 3:
    continue
  print(i)
# Out:
# 0
# 1
# 2
# 4
